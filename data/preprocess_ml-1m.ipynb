# %% [markdown]
# https://grouplens.org/datasets/movielens/1m/

# %%
import pandas as pd
data_root = "../dataset/ml-1m"
ratings = pd.read_csv(f"{data_root}/ratings.dat", sep='::', names=['user', 'item', 'rating', 'timestamp'])
# df_cate = pd.read_csv('movies.dat', sep='::', names=['item', 'title', 'cate'], encoding_errors='ignore')
# df_cate['cate'] = df_cate['cate'].apply(lambda x: x.split('|'))
# df_merge = pd.merge(df, df_cate, on='item', how='left')
# df_merge.drop(labels='title', axis=1, inplace=True)
ratings.to_csv( 
    f"{data_root}/data.csv",
    header=None,
    index=False 
)
print(ratings.shape)
ratings.head()
# Out:
# /tmp/ipykernel_2747872/1651820663.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   ratings = pd.read_csv(f"{data_root}/ratings.dat", sep='::', names=['user', 'item', 'rating', 'timestamp'])
# (1000209, 4)
#    user  item  rating  timestamp
# 0     1  1193       5  978300760
# 1     1   661       3  978302109
# 2     1   914       3  978301968
# 3     1  3408       4  978300275
# 4     1  2355       5  978824291
